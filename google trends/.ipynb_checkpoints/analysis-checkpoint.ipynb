# %%
import pandas as pd

# Load the dataset
file_path = "merged_dataset.csv"
df = pd.read_csv(file_path)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Compute correlation matrix
corr_matrix = df.corr()

# Filter relevant correlations with dengue rates
dengue_corr = corr_matrix[['DengRate_all', 'DengRate_019']].drop(index=['DengRate_all', 'DengRate_019'])

# Plot heatmap
plt.figure(figsize=(10, 12))
sns.heatmap(dengue_corr, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation of Features with Dengue Rates")
plt.show()

# %%
from statsmodels.tsa.stattools import ccf

# Selecting Google Trends and Dengue Rate data
gt_features = ['mosquito_interest', 'sintomas_dengue_interest', 'dengue_interest']
dengue_cases = df['DengRate_all']

# Compute cross-correlation for each Google Trends feature
lags = np.arange(-12, 13)  # Checking lags from -12 to +12 months
ccfs = {feature: ccf(df[feature], dengue_cases)[:len(lags)] for feature in gt_features}

# Plot cross-correlation
plt.figure(figsize=(12, 6))
for feature, values in ccfs.items():
    plt.plot(lags, values, label=feature)

plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel("Lag (Months)")
plt.ylabel("Cross-Correlation")
plt.title("Cross-Correlation Between Google Trends and Dengue Rate")
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# Preparing data for Granger causality test
max_lag = 3  # Testing up to 3-month lead time
granger_results = {}

for feature in gt_features:
    test_data = df[['DengRate_all', feature]].dropna()  # Drop missing values
    granger_test = grangercausalitytests(test_data, max_lag, verbose=False)
    p_values = [granger_test[i][0]['ssr_ftest'][1] for i in range(1, max_lag+1)]  # Extract p-values
    granger_results[feature] = p_values

# Convert results to DataFrame
granger_df = pd.DataFrame(granger_results, index=[f"Lag {i}" for i in range(1, max_lag+1)])
granger_df
# Out:
# c:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# c:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# c:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
#        mosquito_interest  sintomas_dengue_interest  dengue_interest
# Lag 1           0.651613                  0.001858         0.000008
# Lag 2           0.258390                  0.000371         0.074420
# Lag 3           0.142448                  0.000656         0.096462

# %%
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# Preparing features and target variable
X = df.drop(columns=['DengRate_all', 'DengRate_019', 'dep_id'])  # Remove target and state ID
y = df['DengRate_all']

# Standardize features for LASSO
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply LASSO for feature selection
lasso = Lasso(alpha=0.01)  # Regularization strength
lasso.fit(X_scaled, y)

# Extract feature importance
lasso_coeffs = pd.Series(lasso.coef_, index=X.columns)
lasso_coeffs = lasso_coeffs[lasso_coeffs != 0]  # Keep only non-zero coefficients

# Plot LASSO feature importance
plt.figure(figsize=(10, 6))
lasso_coeffs.sort_values().plot(kind='barh', color='steelblue')
plt.xlabel("LASSO Coefficient")
plt.ylabel("Feature")
plt.title("Feature Importance from LASSO Regression")
plt.show()

# %%
# Re-import necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance

# Re-train the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_scaled, y)

# Compute permutation feature importance
perm_importance = permutation_importance(rf_model, X_scaled, y, n_repeats=10, random_state=42)

# Convert to DataFrame
perm_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': perm_importance.importances_mean})
perm_importance_df = perm_importance_df.sort_values(by="Importance", ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 6))
sns.barplot(y=perm_importance_df["Feature"][:15], x=perm_importance_df["Importance"][:15], color="steelblue")
plt.xlabel("Permutation Importance")
plt.ylabel("Feature")
plt.title("Top 15 Feature Importances (Permutation Method)")
plt.show()

# %%
from causalimpact import CausalImpact

# Define pre- and post-periods
pre_period = [0, int(len(df) * 0.7)]  # First 70% of data
post_period = [int(len(df) * 0.7) + 1, len(df) - 1]  # Last 30% of data

# Select the time series for analysis
ci_data = df[['DengRate_all', 'dengue_interest']]  # Dengue cases and Google Trends data

# Run Causal Impact analysis
ci = CausalImpact(ci_data, pre_period, post_period)
ci.plot()
print(ci.summary())
print(ci.summary(output='report'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 12
#      10 # Run Causal Impact analysis
#      11 ci = CausalImpact(ci_data, pre_period, post_period)
# ---> 12 ci.plot()
#      13 print(ci.summary())
#      14 print(ci.summary(output='report'))
#
# File c:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\causalimpact\analysis.py:876, in CausalImpact.plot(self, panels, figsize, fname)
#     873 if isinstance(data_inter, pd.DatetimeIndex):
#     874     data_inter = pd.Timestamp(data_inter)
# --> 876 inferences = self.inferences.iloc[1:, :]
#     878 # Observation and regression components
#     879 if "original" in panels:
#
# AttributeError: 'NoneType' object has no attribute 'iloc'

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train model WITH Google Trends
rf_model_with_gt = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model_with_gt.fit(X_train, y_train)
y_pred_with_gt = rf_model_with_gt.predict(X_test)

# Train model WITHOUT Google Trends
X_no_gt = X.drop(columns=['dengue_interest', 'sintomas_dengue_interest','mosquito_interest'])
X_no_gt_scaled = scaler.fit_transform(X_no_gt)

X_train_no_gt, X_test_no_gt, y_train_no_gt, y_test_no_gt = train_test_split(X_no_gt_scaled, y, test_size=0.2, random_state=42)

rf_model_no_gt = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model_no_gt.fit(X_train_no_gt, y_train_no_gt)
y_pred_no_gt = rf_model_no_gt.predict(X_test_no_gt)

# Compute errors
mae_with_gt = mean_absolute_error(y_test, y_pred_with_gt)
mse_with_gt = mean_squared_error(y_test, y_pred_with_gt)
rmse_with_gt = np.sqrt(mse_with_gt)

mae_no_gt = mean_absolute_error(y_test_no_gt, y_pred_no_gt)
mse_no_gt = mean_squared_error(y_test_no_gt, y_pred_no_gt)
rmse_no_gt = np.sqrt(mse_no_gt)

# Print results
print("Model Performance WITH Google Trends:")
print(f"MAE: {mae_with_gt}, RMSE: {rmse_with_gt}")

print("Model Performance WITHOUT Google Trends:")
print(f"MAE: {mae_no_gt}, RMSE: {rmse_no_gt}")
# Out:
# Model Performance WITH Google Trends:
# MAE: 0.0053251297217619484, RMSE: 0.025638203259404503
# Model Performance WITHOUT Google Trends:
# MAE: 0.004605741901474655, RMSE: 0.0224784226817119

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import grangercausalitytests, acf, pacf
import statsmodels.api as sm

# Load dataset
file_path = "merged_dataset.csv"  # Update if needed
df = pd.read_csv(file_path)  # Adjust 'date_column'

# Ensure data is sorted by time
# df = df.sort_index()

# Columns for analysis
google_trends_cols = ['mosquito_interest', 'sintomas_dengue_interest', 'dengue_interest']
target_col = 'DengRate_all'  # Adjust to actual dengue cases column

### 1. CROSS-CORRELATION ANALYSIS (Find Best Lags/Leads) ###
def cross_correlation(series_x, series_y, max_lag=12):
    """Compute cross-correlation for lags (-max_lag to +max_lag)"""
    lags = range(-max_lag, max_lag + 1)
    correlations = [series_x.shift(lag).corr(series_y) for lag in lags]
    
    plt.figure(figsize=(10, 5))
    plt.stem(lags, correlations)  # Removed 'use_line_collection=True'
    plt.axhline(y=0, color='black', linewidth=1)
    plt.axhline(y=0.2, linestyle="--", color="gray")
    plt.axhline(y=-0.2, linestyle="--", color="gray")
    plt.title(f"Cross-Correlation with {series_x.name}")
    plt.xlabel("Months Lagged")
    plt.ylabel("Correlation")
    plt.grid()
    plt.show()


# Run Cross-Correlation for each Google Trends column
for col in google_trends_cols:
    print(f"Cross-correlation for {col}")
    cross_correlation(df[col], df[target_col])

### 2. GRANGER CAUSALITY TEST ###
def granger_test(df, max_lag=6):
    """Runs Granger Causality test for each Google Trends column"""
    for col in google_trends_cols:
        print(f"\n=== Granger Causality Test: {col} → {target_col} ===")
        test_result = grangercausalitytests(df[[target_col, col]], max_lag, verbose=True)
    
# Run Granger Causality Test
granger_test(df)

### 3. ACF/PACF ANALYSIS FOR GOOGLE TRENDS COLUMNS ###
def plot_acf_pacf(series, lags=12):
    """Plots ACF and PACF for a given series"""
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    sm.graphics.tsa.plot_acf(series, lags=lags, ax=axes[0])
    axes[0].set_title(f"ACF of {series.name}")
    
    sm.graphics.tsa.plot_pacf(series, lags=lags, ax=axes[1])
    axes[1].set_title(f"PACF of {series.name}")
    
    plt.tight_layout()
    plt.show()

# Run ACF/PACF for each Google Trends column
for col in google_trends_cols:
    print(f"\nACF/PACF for {col}")
    plot_acf_pacf(df[col])
# Out:
# Cross-correlation for mosquito_interest
# Cross-correlation for sintomas_dengue_interest
# Cross-correlation for dengue_interest
# === Granger Causality Test: mosquito_interest → DengRate_all ===
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2039  , p=0.6516  , df_denom=5180, df_num=1
# ssr based chi2 test:   chi2=0.2040  , p=0.6515  , df=1
# likelihood ratio test: chi2=0.2040  , p=0.6515  , df=1
# parameter F test:         F=0.2039  , p=0.6516  , df_denom=5180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3536  , p=0.2584  , df_denom=5177, df_num=2
# ssr based chi2 test:   chi2=2.7099  , p=0.2580  , df=2
# likelihood ratio test: chi2=2.7092  , p=0.2581  , df=2
# parameter F test:         F=1.3536  , p=0.2584  , df_denom=5177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8132  , p=0.1424  , df_denom=5174, df_num=3
# ssr based chi2 test:   chi2=5.4468  , p=0.1419  , df=3
# likelihood ratio test: chi2=5.4440  , p=0.1420  , df=3
# parameter F test:         F=1.8132  , p=0.1424  , df_denom=5174, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3906  , p=0.2345  , df_denom=5171, df_num=4
# ssr based chi2 test:   chi2=5.5720  , p=0.2335  , df=4
# likelihood ratio test: chi2=5.5690  , p=0.2337  , df=4
# parameter F test:         F=1.3906  , p=0.2345  , df_denom=5171, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3695  , p=0.2324  , df_denom=5168, df_num=5
# ssr based chi2 test:   chi2=6.8620  , p=0.2311  , df=5
# likelihood ratio test: chi2=6.8575  , p=0.2315  , df=5
# parameter F test:         F=1.3695  , p=0.2324  , df_denom=5168, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8085  , p=0.0933  , df_denom=5165, df_num=6
# ssr based chi2 test:   chi2=10.8784 , p=0.0922  , df=6
# likelihood ratio test: chi2=10.8670 , p=0.0926  , df=6
# parameter F test:         F=1.8085  , p=0.0933  , df_denom=5165, df_num=6
#
# === Granger Causality Test: sintomas_dengue_interest → DengRate_all ===
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.6948  , p=0.0019  , df_denom=5180, df_num=1
# ssr based chi2 test:   chi2=9.7004  , p=0.0018  , df=1
# likelihood ratio test: chi2=9.6913  , p=0.0019  , df=1
# parameter F test:         F=9.6948  , p=0.0019  , df_denom=5180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.9119  , p=0.0004  , df_denom=5177, df_num=2
# ssr based chi2 test:   chi2=15.8390 , p=0.0004  , df=2
# likelihood ratio test: chi2=15.8149 , p=0.0004  , df=2
# parameter F test:         F=7.9119  , p=0.0004  , df_denom=5177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.7285  , p=0.0007  , df_denom=5174, df_num=3
# ssr based chi2 test:   chi2=17.2088 , p=0.0006  , df=3
# likelihood ratio test: chi2=17.1803 , p=0.0006  , df=3
# parameter F test:         F=5.7285  , p=0.0007  , df_denom=5174, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.6450  , p=0.0010  , df_denom=5171, df_num=4
# ssr based chi2 test:   chi2=18.6122 , p=0.0009  , df=4
# likelihood ratio test: chi2=18.5788 , p=0.0010  , df=4
# parameter F test:         F=4.6450  , p=0.0010  , df_denom=5171, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.8248  , p=0.0018  , df_denom=5168, df_num=5
# ssr based chi2 test:   chi2=19.1647 , p=0.0018  , df=5
# likelihood ratio test: chi2=19.1293 , p=0.0018  , df=5
# parameter F test:         F=3.8248  , p=0.0018  , df_denom=5168, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.9974  , p=0.0063  , df_denom=5165, df_num=6
# ssr based chi2 test:   chi2=18.0296 , p=0.0062  , df=6
# likelihood ratio test: chi2=17.9983 , p=0.0062  , df=6
# parameter F test:         F=2.9974  , p=0.0063  , df_denom=5165, df_num=6
#
# === Granger Causality Test: dengue_interest → DengRate_all ===
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=20.0914 , p=0.0000  , df_denom=5180, df_num=1
# ssr based chi2 test:   chi2=20.1031 , p=0.0000  , df=1
# likelihood ratio test: chi2=20.0642 , p=0.0000  , df=1
# parameter F test:         F=20.0914 , p=0.0000  , df_denom=5180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5993  , p=0.0744  , df_denom=5177, df_num=2
# ssr based chi2 test:   chi2=5.2037  , p=0.0741  , df=2
# likelihood ratio test: chi2=5.2011  , p=0.0742  , df=2
# parameter F test:         F=2.5993  , p=0.0744  , df_denom=5177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.1123  , p=0.0965  , df_denom=5174, df_num=3
# ssr based chi2 test:   chi2=6.3454  , p=0.0960  , df=3
# likelihood ratio test: chi2=6.3415  , p=0.0961  , df=3
# parameter F test:         F=2.1123  , p=0.0965  , df_denom=5174, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6163  , p=0.1672  , df_denom=5171, df_num=4
# ssr based chi2 test:   chi2=6.4766  , p=0.1663  , df=4
# likelihood ratio test: chi2=6.4726  , p=0.1665  , df=4
# parameter F test:         F=1.6163  , p=0.1672  , df_denom=5171, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5116  , p=0.1825  , df_denom=5168, df_num=5
# ssr based chi2 test:   chi2=7.5743  , p=0.1813  , df=5
# likelihood ratio test: chi2=7.5687  , p=0.1817  , df=5
# parameter F test:         F=1.5116  , p=0.1825  , df_denom=5168, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5349  , p=0.1624  , df_denom=5165, df_num=6
# ssr based chi2 test:   chi2=9.2323  , p=0.1609  , df=6
# likelihood ratio test: chi2=9.2241  , p=0.1614  , df=6
# parameter F test:         F=1.5349  , p=0.1624  , df_denom=5165, df_num=6
#
# ACF/PACF for mosquito_interest
# C:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\Gautam\anaconda3\envs\minornew\lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# ACF/PACF for sintomas_dengue_interest
# ACF/PACF for dengue_interest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Load the dataset
file_path = "merged_dataset.csv"
df = pd.read_csv(file_path)

# Creating multiple lagged and lead versions of GT data
lags = [1, 2, 3]  # Months to shift backward
leads = [1, 2]  # Months to shift forward

gt_features = ['mosquito_interest', 'sintomas_dengue_interest', 'dengue_interest']

# # Apply lag
# for lag in lags:
#     for feature in gt_features:
#         df[f'{feature}_lag{lag}'] = df[feature].shift(lag)

# Apply lead
# df_lead=df
for lead in leads:
    df_lead=df.copy()
    for feature in gt_features:
        df_lead[f'{feature}_lead{lead}'] = df[feature].shift(-lead)  # Shift forward (future data)
    df_lead=df_lead.drop(columns=gt_features)

    # Define feature set with new lags and leads
    X_lag_lead = df_lead.drop(columns=['DengRate_all'])  # Keep all lag/lead GT features
    y = df_lead['DengRate_all']

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X_lag_lead, y, test_size=0.2, random_state=42)

    # Train model WITH all lag/lead features
    rf_model_with_lags = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model_with_lags.fit(X_train, y_train)
    y_pred_with_lags = rf_model_with_lags.predict(X_test)

    # Train model WITHOUT Google Trends (baseline)
    X_no_gt = df_lead.drop(columns=['DengRate_all']  + [f'{f}_lead{lead}' for f in gt_features])
    # X_no_gt_scaled = scaler.fit_transform(X_no_gt)

    X_train_no_gt, X_test_no_gt, y_train_no_gt, y_test_no_gt = train_test_split(X_no_gt, y, test_size=0.2, random_state=42)

    rf_model_no_gt = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model_no_gt.fit(X_train_no_gt, y_train_no_gt)
    y_pred_no_gt = rf_model_no_gt.predict(X_test_no_gt)

    # Compute errors
    mae_with_lags = mean_absolute_error(y_test, y_pred_with_lags)
    rmse_with_lags = np.sqrt(mean_squared_error(y_test, y_pred_with_lags))

    mae_no_gt = mean_absolute_error(y_test_no_gt, y_pred_no_gt)
    rmse_no_gt = np.sqrt(mean_squared_error(y_test_no_gt, y_pred_no_gt))

    # Print results
    print("Model Performance WITH Google Trends (Lags & Leads):")
    print(f"MAE: {mae_with_lags}lead:{lead}, RMSE: {rmse_with_lags}lead:{lead}")

    print("Model Performance WITHOUT Google Trends: ")
    print(f"MAE: {mae_no_gt}, RMSE: {rmse_no_gt}")

    # print(df_lead.columns)
    # print(df.columns)
    # df_lead=df_lead.drop(columns=[f'{f}_lead{lead}' for f in gt_features])
# Out:
# Model Performance WITH Google Trends (Lags & Leads):
# MAE: 0.0031528871669646527lead:1, RMSE: 0.00959275916132887lead:1
# Model Performance WITHOUT Google Trends:
# MAE: 0.003155947562089583, RMSE: 0.009545484838587429
# Model Performance WITH Google Trends (Lags & Leads):
# MAE: 0.0031670126564722328lead:2, RMSE: 0.00966771447351937lead:2
# Model Performance WITHOUT Google Trends:
# MAE: 0.003155947562089583, RMSE: 0.009545484838587429

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Load the dataset
file_path = "merged_dataset.csv"
df = pd.read_csv(file_path)

# Creating multiple lagged and lead versions of GT data
lags = [1, 2, 3]  # Months to shift backward
leads = [1, 2]  # Months to shift forward

gt_features = ['mosquito_interest', 'sintomas_dengue_interest', 'dengue_interest']

# Apply lag
for lag in lags:
    df_lag=df.copy()
    for feature in gt_features:
        df_lag[f'{feature}_lag{lag}'] = df[feature].shift(lag)
    df_lagdf_lag.drop(columns=gt_features)
# Apply lead
# df_lead=df
# for lead in leads:
#     df_lead=df.copy()
#     for feature in gt_features:
#         df_lead[f'{feature}_lead{lead}'] = df[feature].shift(-lead)  # Shift forward (future data)
#     df_lead=df_lead.drop(columns=gt_features)

    # Define feature set with new lags and leads
    X_lag_lead = df_lead.drop(columns=['DengRate_all'])  # Keep all lag/lead GT features
    y = df_lead['DengRate_all']

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X_lag_lead, y, test_size=0.2, random_state=42)

    # Train model WITH all lag/lead features
    rf_model_with_lags = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model_with_lags.fit(X_train, y_train)
    y_pred_with_lags = rf_model_with_lags.predict(X_test)

    # Train model WITHOUT Google Trends (baseline)
    X_no_gt = df_lead.drop(columns=['DengRate_all']  + [f'{f}_lead{lead}' for f in gt_features])
    # X_no_gt_scaled = scaler.fit_transform(X_no_gt)

    X_train_no_gt, X_test_no_gt, y_train_no_gt, y_test_no_gt = train_test_split(X_no_gt, y, test_size=0.2, random_state=42)

    rf_model_no_gt = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model_no_gt.fit(X_train_no_gt, y_train_no_gt)
    y_pred_no_gt = rf_model_no_gt.predict(X_test_no_gt)

    # Compute errors
    mae_with_lags = mean_absolute_error(y_test, y_pred_with_lags)
    rmse_with_lags = np.sqrt(mean_squared_error(y_test, y_pred_with_lags))

    mae_no_gt = mean_absolute_error(y_test_no_gt, y_pred_no_gt)
    rmse_no_gt = np.sqrt(mean_squared_error(y_test_no_gt, y_pred_no_gt))

    # Print results
    print("Model Performance WITH Google Trends (Lags & Leads):")
    print(f"MAE: {mae_with_lags}lead:{lead}, RMSE: {rmse_with_lags}lead:{lead}")

    print("Model Performance WITHOUT Google Trends: ")
    print(f"MAE: {mae_no_gt}, RMSE: {rmse_no_gt}")

    # print(df_lead.columns)
    # print(df.columns)
    # df_lead=df_lead.drop(columns=[f'{f}_lead{lead}' for f in gt_features])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 20
#      18     for feature in gt_features:
#      19         df_lead[f'{feature}_lead{lead}'] = df[feature].shift(lag)
# ---> 20     df_lead=df_lead.drop(columns=gt_features)
#      21 # Apply lead
#      22 # df_lead=df
#      23 # for lead in leads:
#    (...)
#      28
#      29     # Define feature set with new lags and leads
#      30     X_lag_lead = df_lead.drop(columns=['DengRate_all'])  # Keep all lag/lead GT features
#
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\envs\minornew\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['mosquito_interest', 'sintomas_dengue_interest', 'dengue_interest'] not found in axis"
